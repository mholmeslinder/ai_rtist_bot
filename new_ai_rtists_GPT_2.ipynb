# %% [markdown]
# <a href="https://colab.research.google.com/github/mholmeslinder/ai_rtist_bot/blob/master/new_ai_rtists_GPT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 2: Finetuning GPT-2 on our dataset and spitting out 'new artists'
#
# ### This is totally based on the awesome [GPT-2-Simple](https://github.com/minimaxir/gpt-2-simple) and its associated Colab.
#
# In [Part 1](https://github.com/mholmeslinder/ai_rtist_bot/blob/master/bot_ml_repo/new_ai_rtists_dataset.ipynb), we used the Last.fm API to collect our dataset - a list of ~10,000 names of real musical artists. In this Colab, we'll be retraining [OpenAI's GPT-2](https://openai.com/blog/better-language-models/) on that data and getting it to spit out some fictional 'new artist names', which we will run through our ["cleaner"](https://github.com/mholmeslinder/ai_rtist_bot/blob/master/bot_ml_repo/cleaner.py), removing any items that duplicate our existing dataset.
#
# At that point, we'll have a list of 'new artist names', which we can use for whatever purpose we want!

# %% [markdown]
# ## Imports.

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
#   Building wheel for gpt-2-simple (setup.py) ... done
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## GPU
#
# Here's what Max Woolf says in his [brilliant Colab](https://colab.research.google.com/drive/1VLG8e7YSEwypxU-noRNhsv5dW4NfTGce):
#
# "Colaboratory uses either a Nvidia T4 GPU or an Nvidia K80 GPU. The T4 is slightly faster than the old K80 for training GPT-2, and has more memory allowing you to train the larger GPT-2 models and generate more text.
#
# You can verify which GPU is active by running the cell below."

# %%
# !nvidia-smi
# Out:
# Sat Mar  7 01:08:25 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.59       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     7W /  75W |      0MiB /  7611MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Download GPT-2
# We'll be training on GPT-2's Medium (355M) model. If you'd like more info about the different models of GPT-2 that OpenAI released, you can check out the GPT-2-Simple links in the cells above or on [OpenAI's site](https://openai.com/blog/gpt-2-1-5b-release/).

# %%
gpt2.download_gpt2(model_name="355M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 299Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 100Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 608Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:05, 278Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 279Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 114Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 167Mit/s]

# %% [markdown]
# ## Dataset File
#
# In theaforementioned totally awesome Colab, he advises mounting Drive as a way to upload datasets for our model to crunch on. This is an excellent idea, and I highly recommend it for most Colab purposes.
#
# Since, for the purposes of documenting our [Twitter Bot](https://twitter.com/new_ai_rtists), we only need one dataset, we'll instead run the following code to grab it from our [Github repo](https://github.com/mholmeslinder/ai_rtist_bot).

# %%
# !git clone https://github.com/mholmeslinder/ai_rtist_bot
file_name = "ai_rtist_bot/data/artist_names.txt"
# Out:
# Cloning into 'ai_rtist_bot'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 70 (delta 28), reused 63 (delta 21), pack-reused 0
# Unpacking objects: 100% (70/70), done.

# %% [markdown]
# ## Finetune GPT-2
#
# Here, I will again c+p from Max Woolf's awesome colab:
#
# "The next cell will start the actual finetuning of GPT-2. It creates a persistent TensorFlow session which stores the training config, then runs the training for the specified number of `steps`. (to have the finetuning run indefinitely, set `steps = -1`)
#
# The model checkpoints will be saved in `/checkpoint/run1` by default. The checkpoints are saved every 500 steps (can be changed) and when the cell is stopped.
#
# The training might time out after 4ish hours; make sure you end training and save the results so you don't lose them!
#
# **IMPORTANT NOTE:** If you want to rerun this cell, **restart the VM first** (Runtime -> Restart Runtime). You will need to rerun imports but not recopy files.
#
# Other optional-but-helpful parameters for `gpt2.finetune`:
#
#
# *  **`restore_from`**: Set to `fresh` to start training from the base GPT-2, or set to `latest` to restart training from an existing checkpoint.
# * **`sample_every`**: Number of steps to print example output
# * **`print_every`**: Number of steps to print training progress.
# * **`learning_rate`**:  Learning rate for the training. (default `1e-4`, can lower to `1e-5` if you have <1MB input data)
# *  **`run_name`**: subfolder within `checkpoint` to save the model. This is useful if you want to work with multiple models (will also need to specify  `run_name` when loading the model)
# * **`overwrite`**: Set to `True` if you want to continue finetuning an existing model (w/ `restore_from='latest'`) without creating duplicate copies."

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='355M',
              steps=1000,
              restore_from='latest',
              run_name='run3',
              print_every=10,
              sample_every=200,
              save_every=500
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  1.81it/s]
# dataset has 43571 tokens
# Training...
# [10 | 32.03] loss=3.75 avg=3.75
# [20 | 53.97] loss=4.24 avg=4.00
# [30 | 75.94] loss=3.61 avg=3.87
# [40 | 97.99] loss=3.27 avg=3.72
# [50 | 120.07] loss=3.45 avg=3.66
# [60 | 142.13] loss=2.55 avg=3.47
# [70 | 164.25] loss=4.12 avg=3.57
# [80 | 186.40] loss=3.94 avg=3.61
# [90 | 208.48] loss=2.64 avg=3.50
# [100 | 230.57] loss=2.47 avg=3.39
# [110 | 252.71] loss=2.62 avg=3.32
# [120 | 274.83] loss=2.75 avg=3.27
# [130 | 296.93] loss=2.81 avg=3.23
# [140 | 319.06] loss=2.23 avg=3.16
# [150 | 341.20] loss=2.29 avg=3.09
# [160 | 363.36] loss=3.20 avg=3.10
# [170 | 385.47] loss=1.95 avg=3.03
# [180 | 407.64] loss=2.29 avg=2.98
# [190 | 429.74] loss=2.76 avg=2.97
# [200 | 451.88] loss=2.59 avg=2.95
# ======== SAMPLE 1 ========
#
# Bobby Hebb
# Mariah Montage
# Lorne Balfe
# The Magician
# The Kooks
# Bobby Wilson
# Caleb Belkin
# Mobb Deep
# Kelsey Lu
# Jadakiss
# The Dap-Kings
# Yvonne Elliman
# Clara Nunes
# Jawbreaker
# Maggie Lindemann
# Blues Traveler
# M. Ward
# The Magician
# Pierce Fulton
# Lorena
# Fela Kuti
# Gang Starr
# Aurora A.M.
# Bobby McFerrin
# NCT 127
# Fozzy
# Aurora
# Au5
# Dierks Bentley
# Jukebox the Ghost
# Junkie XL
# Jules Massenet
# Wand
# Nephew of the Ak-S
# Bobby Caldwell
# Dusseldorf
# Mogwai
# Aurora
# A.C.E.
# The Magnetic Fields
# The Pointer Sisters
# Ariel Lemon
# Beth Orton
# O.T. Genasis
# Blind Pilot
# Orla Gartland
# Vader
# Cazzu
# Erik Satie
# The Magnetic Fields
# Ce Ce Penseau
# Jazz Cartier
# Loreena Du Maurier
# Gladys Knight & the Supremes
# Caroline Shaw
# Celia Cruz
# Jurnee Smollett-Bell
# Molly Gevinson
# Ariel Pink
# Cecilia Hatchet
# Karen Harding
# Vader
# Bobby
# The Magician
# Cidade Negra
# Buddy Holly
# Kenny Rogers
# The Sounds
# The Magnetic Fields
# Car Bomb
# Cidade Red
# The Magnetic Fields
# The Sounds
# The Magician
# Marina & the Diamonds
# Bruno Tama
# Yubin Rawansky
# Sidney Bechet
# The Magnetic Fields
# E-40
# Kasper Lindmark
# Mt. Wolf
# Sidney Bechet
# Alok
# Rathbun Pickups
# Hockey Dad
# Chris Lorenzo
# John Baizley
# Yook & Scobee
# Lionel Richie
# Kasper Lindmark
# Lucy Dacus
# Lux
# Oliver Sing Profile
# Ленинга
# Oliver Heldens
# Lux & Tróia
# Forth Wanderers
# The Magician
# The Soundtrack
# Oliver Schories
# Mija
# Johann Sebastian Bach, D.C.
# Oliver O'Hara
# Paddy and the Rats
# The Sounds
# The Magnetic Fields
# Tory Lanez
# Jub Jaws
# Bobby "Butthole Surfers" Bland
# The Magician
# The Sounds
# The Prodigy
# Olly Murs
# Акван Кристи
# Candi Staton
# Clem Leek
# Yuksek
# James Murphy
# Банкц-Zamfir
# Yuksek
# The Magnetic Fields
# ОООМI
# Cream Soda
# Titus Andronicus
# The Sounds
# Bobby Vinton
# The Magnetic Fields
# Мельнир
# Luxottica
# The Sounds
# Селоры
# Doomtree
# Dilma Luna
# Ezra Shaw
# Paddy butthole
# Doomtree
# Pentakill
# Nataofi
# The Automatic
# Fela Kuti
# Cynthia Luz
# Jello Biafra
# Zimmer
# Гриб
# Maurice Ravel
# Luxes
# Nada Surf
# Nora En Pure
# Francie Stooge
# Ельзинает
# Savage Ga$p
# Perturbator
# John Baitz
# Luxottica
# The Magician
# Claud
# T.R.U.
# Roc Marciano
# Bobby "Blue" Bland
# Ezra Collective
# K. Michelle
# The Sounds
# Слот
# Claud
# Мы
# Bobby Hebb
# АлисА
# Eric Bellinger
# Savage Love Songs
# Fonfara Sound Machine
# D.J. Guyer
# Vacation Manor
# Savage Ga$p
# The Magnetic Fields
# Павлецки
# G. Love & Special Sauce
# Стравс
# G. Ross Markus
# Манетинованые Снайгаина
# FoulBeats
# Kraak & Van Der Sanden
# Langhorne Slim
# АлисА
# Black
# The Physical State
# Yvonne Elliman
# Chad Lawson
# Younotus
# The Magnetic Fields
# Пай
#
# [210 | 505.24] loss=3.55 avg=2.98
# [220 | 527.50] loss=1.44 avg=2.90
# [230 | 549.69] loss=1.43 avg=2.83
# [240 | 571.86] loss=1.48 avg=2.77
# [250 | 594.07] loss=1.61 avg=2.72
# [260 | 616.26] loss=1.35 avg=2.66
# [270 | 638.43] loss=1.73 avg=2.62
# [280 | 660.59] loss=1.66 avg=2.58
# [290 | 682.80] loss=1.39 avg=2.53
# [300 | 704.98] loss=1.69 avg=2.50
# [310 | 727.15] loss=1.67 avg=2.47
# [320 | 749.28] loss=1.03 avg=2.42
# [330 | 771.46] loss=0.91 avg=2.36
# [340 | 793.63] loss=1.02 avg=2.32
# [350 | 815.79] loss=1.25 avg=2.28
# [360 | 837.92] loss=1.15 avg=2.24
# [370 | 860.11] loss=0.68 avg=2.19
# [380 | 882.32] loss=0.54 avg=2.14
# [390 | 904.51] loss=0.32 avg=2.09
# [400 | 926.77] loss=0.75 avg=2.05
# ======== SAMPLE 1 ========
# T.S. (The) Wailers
# Tommy Hilfiger
# Lena
# Charles
# Ol' Dirty Bastard
# Tom Grennan
# Roberto Carlos
# Detonautas Roque Clube
# Roberto Carlos
# Da Tweekaz
# Charles Gounod
# Jependraph
# Marianas Trench
# My Morning Jacket
# Charles S. Miller
# Lawrence
# Blonde Redhead
# Teejay
# Marc E. Criola
# ØDYSSEE
# ØDYSSEE
# Methyl Ethel
# Travie Recordings
# Dwayne Johnson
# Lil Tipper
# Danger Mouse
# Travis
# I'm With Her
# Jai Wolf
# Bryant Myers
# Lotte Kestner
# Kevin Abstract
# Danger City
# Bread
# Kurt Bohan
# Charles Bolt
# Julian Cope
# Ruelle
# Misþ
# At the Gates
# Trent Reznor
# God Is An Astronaut
# Bodega
# LIL PUMP
# Rednex
# Johannes Brahms
# Trophy Eyes
# Kidd Keo
# Duffy
# LIL PUMP
# Trevor Something
# Triathalon
# Adam Beyer
# Digitalism
# Jitka
# Ethan Gruska
# Ethan Grunberg
# Jay Grunberg
# Guustavv
# Pale Waves
# Trent Reznor
# Lookout!
# Jumper
# Billy Currington
# Kinda Like Jets
# Bear's Eye
# LIL PUMP
# Johannes Brahms
# Trophy Eyes
# Kurt Cobain
# Blood Orange
# Cobi
# Trent Reznor
# Look At Me Now
# Tyler Childers
# Alessandro Cortini
# Leonard Bernstein
# I'm With Her
# Johannes Brahms
# John Denver
# Alessra
# Elliphant
# Shintaro Hayek
# Trent Reznor
# Look Who's Talking
# JOYNER LOUIS
# Gin Wigmore
# Pharaoh
# Big Star
# St. Vincent
# Eurythmics
# LIL BO WEEP
# Johnny Lightning
# Carrie Underwood
# Blondie
# Sleepermane
# Franz Liszt
# Bag Raiders
# Ayo & Teo
# Kevin Ayers
# The Underachievers
# Daran
# Sampha
# Trippie Redd
# YBN Nahmir
# Bolt Thrower
# Sabina Ddumba
# Gedz
# Ravage
# Rafael Anton Irisarri
# Kublai Khan TX
# Allday
# Sir Was
# Camilo
# Johannes Brahms
# Celly
# D-Block Europe
# Chico Science & The Hyena
# Rau Wroldsen
# Eleni Laaksonen
# Train
# Roy Price
# Kevin Alberts
# Chico Science & The Visualizer
# Sensi Sye
# Jamila Woods
# Robin S
# Pinkjr
# Trent Reznor
# Magic Sword
# Lady Sings
# Camilo
# Teodor Wolgers
# VHS DREAMS
# Freddie Gibbs & Madlib
# All That Remains
# Britney Spears
# Workaholics
# Lewis OfMan
# A Thousand Planets
# Hatus
# Dead Man's Bones
# Joseph Williams
# Dr. Dogg
# Mrrth
# Tyler Ward
# Samm Henshaw
# Schmilco
# Julieta Lima
# Herz
# Jorn
# Kortney
# Voxtrot
# Static-X
# Doris Paquet
# John Frusciante
# Rodeo Drive
# Kreator
# LIL PEEP
# Maniacal Pong
# Ravishank Roy
# Bass Thief
# Danger Mouse
# Digitalism
# Dangers Close
# Screaming Trees
# Chase Rice
# Lil Jon & The Wailers
# Blind Faith
# Empress Of
# Julieta Lima
# Tiny Rhino
# Blr
# Disturbed
# Haywyre
# Tom Szarabajka
# Banks
# WRLD
# Aero Flob
# Tomasz Kraal
# Ibeyi
# Snavs
# Charlotte Cardin
# Ekali
# LIL PEEP
# Camellia
# Chris Cornell
# John Lee Hooker
# Carrie Underwood
# Tiny Moving Parts
# Ben Kweller
# Comeback Kid
# Johannes Brahms
# Tiny Moving Parts
# Roc Marciano
# WRLD
# Dmitry Evgrafov
# Bad Wild Love
# Gilberto Gil
# Manowar
# The Atomic Rats
# Boris
# Kortez
# Andrew McMahon in the Wilderness
# Large Professor
# Dr. Hook
# Meteor
# Bolt Thrower
# Rasmentalism
# Goth Babe
# Chico Science & The Visualizer
# Lucy Dacus
# Kasbo
# Shout Out Louds
# S U R L D I Z O N A
# JOYNER LOUIS
# Kasbo
#
# [410 | 977.87] loss=0.88 avg=2.01
# [420 | 1000.13] loss=1.10 avg=1.98
# [430 | 1022.36] loss=0.30 avg=1.94
# [440 | 1044.57] loss=0.35 avg=1.89
# [450 | 1066.76] loss=0.29 avg=1.85
# [460 | 1088.96] loss=0.16 avg=1.80
# [470 | 1111.21] loss=0.44 avg=1.77
# [480 | 1133.43] loss=0.68 avg=1.74
# [490 | 1155.64] loss=0.13 avg=1.70
# [500 | 1177.87] loss=0.08 avg=1.66
# Saving checkpoint/run3/model-500
# [510 | 1207.89] loss=0.35 avg=1.62
# [520 | 1230.14] loss=1.27 avg=1.61
# [530 | 1252.31] loss=0.10 avg=1.58
# [540 | 1274.52] loss=0.18 avg=1.54
# [550 | 1296.70] loss=0.07 avg=1.51
# [560 | 1318.97] loss=0.05 avg=1.48
# [570 | 1341.19] loss=0.08 avg=1.44
# [580 | 1363.43] loss=0.05 avg=1.41
# [590 | 1385.64] loss=0.05 avg=1.38
# [600 | 1407.88] loss=0.04 avg=1.35
# ======== SAMPLE 1 ========
# con
# Vancouver Sleep Clinic
# Leven Kali
# Fetty Wap
# Bonobo
# Fischerspooner
# Turisas
# Laura Branigan
# Prince
# Impala
# Britney Spears
# Angel Olsen
# Caroline Polachek
# New Kids on the Block
# Gramatik
# Gugu Mbatha
# YFN Lucci
# Japanese Breakfast
# Darlingside
# Franz Liszt
# Bobby McFerrin
# Gary Moore
# JMSN
# key
# Mac Miller
# Samples
# Kenny Wayne Shepherd Band
# Bassnectar
# Future of the Year
# Adele
# Elton John
# Nicolas Godin
# Damien Rice
# Beyoncé
# Beyoncé
# Beyoncé
# Beyoncé
# Mac Miller
# Taylor Swift
# 1Kilo
# Lorde
# Franz Ferdinand
# Chris Brown
# John Mayer
# Wolf Alice
# Beyoncé
# Beyoncé
# Mac Miller
# Ari Taylor
# 1Uniform
# Avicii
# 1Cocteau Twins
# Niall Horan
# Sam Godder
# Sam Smith
# 1CunninLynguists
# JMSN
# alt-J
# Lorde
# Paul Kim
# Alt-J
# Madonna
# Blonde Redhead
# Alicia Keys
# Bruce Springsteen
# Dolly Parton
# Superorganism
# Superorganism
# Wiz Khalifa
# All Saints
# J Balvin
# Beyoncé
# Beyoncé
# Sia
# Swedish House Mafia
# Black Kids
# Alton Ellis
# Blake Rose
# Cory Thomas
# Omaur
# Anderson .Paak
# Literally
# Mahalia Jackson
# Cold
# Deaton Chris Anthony
# Jr. Walker & The Wayls
# Lil Wayne
# Blondie
# The Kinks
# Meghan Trainor
# Imagine Dragons
# Taylor Swift
# Blondie
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Fifth Harmony
# The Stooges
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Imagine Dragons
# Twenty One Pilots
# Fifth Harmony
# Sia
# Tenacious D
# Future
# Panic! at the Disco
# Birocratic
# Souls of Mischief
# Destiny's Child
# Sabrina Claudio
# EDX
# Hiatus
# JD McPherson
# Birocratic
# Motley Crue
# CunninLynguists
# Future
# Apollo Brown
# Mariah Carey
# King Princess
# Girls Aloud
# The Weeknd
# Alicia Keys
# Anderson .Paak
# Vic Mensa
# Beastie Boys
# The Real Deal
# The Proclaimers
# Genix
# A$AP Rocky
# Shawn Mendes
# Perfume
# Wolf Alice
# Kesha
# Mura Kami
# Slushii
# Gwyneth Paltrow
# Coheed and Cambria
# Bushbaby
# Yandel
# Summer Ketchum
# Fianna
# Sky Ferreira
# Khart
# KRS-One
# Lil Wayne
# Big Sean
# Lauv
# Jorge Blanco
# Demi Lovato
# Blackbear
# 5 Seconds of Summer
# Funky DL
# Troye Sivan
# We Are Scientists
# Lil Wayne
# Coldplay
# Ke$ha
# Radiohead
# OK Go
# Shania Twain
# Alice in Chains
# Gui Boratto
# Skylar Grey
# Barry White
# SWV
# Air
# Kelly Clarkson
# Betty Wright
# Tip Top
# Charlie Puth
# Major Lazer
# Chance the Rapper
# Charlie Puth
# Interpol
# 5 Seconds of Summer
# Japanese Breakfast
# Japanese Girls
# Interpol
# Iceage
# Bruno Piedrah
# Japanese Breakfast
# Japanese Women
# Japanese Football
# Female
# Fidlar
# Björk
# Tkay Maidza
# Muna
# Rick Astley
# Lil Wayne
# 여자친구
# Flor
# Ricky Rubio
# Universal
# Jase Cohen
# Europa
# Adele
# Alabama Get Ready
# Alabama Getaway
# Hyolyn
# Alabama Juke Mafia
# Tessa Violet
# Alabama Shakes
# Kevin Garrett
# CNCO
# Alabama Get Ready
# Azriel
# Łona
# Alabama Joint Union
# IAINI
# Alabama Shakes
# King Geedorah
# Justin Bieber
# Cozy Collective
# Antibal Salvatore
# John Martyn
# Union Station
# Texas Shakes
# Ohio Players
# James Arthur
# Lorna Shore
# Black Coffee
# Martin Jensen
# INTERSTELLAR
# ramz
# Hugo
# Georgia
# Alabama Cravings
# Craft Council
# The Aqu
#
# [610 | 1459.03] loss=0.06 avg=1.32
# [620 | 1481.31] loss=0.05 avg=1.30
# [630 | 1503.56] loss=0.08 avg=1.27
# [640 | 1525.77] loss=0.03 avg=1.24
# [650 | 1547.96] loss=0.11 avg=1.22
# [660 | 1570.19] loss=0.08 avg=1.20
# [670 | 1592.39] loss=0.04 avg=1.17
# [680 | 1614.65] loss=0.04 avg=1.15
# [690 | 1636.93] loss=0.05 avg=1.13
# [700 | 1659.16] loss=0.08 avg=1.11
# [710 | 1681.41] loss=0.02 avg=1.09
# [720 | 1703.67] loss=0.06 avg=1.07
# [730 | 1725.93] loss=0.06 avg=1.05
# [740 | 1748.14] loss=0.03 avg=1.03
# [750 | 1770.42] loss=0.08 avg=1.01
# [760 | 1792.64] loss=0.03 avg=0.99
# [770 | 1814.89] loss=0.05 avg=0.97
# [780 | 1837.13] loss=0.05 avg=0.96
# [790 | 1859.41] loss=0.04 avg=0.94
# [800 | 1881.63] loss=0.05 avg=0.92
# ======== SAMPLE 1 ========
# yla
# Primordial
# Powers Pleasant
# Average White Band
# Foy Vance
# Kayne West
# Kadebostany
# Alexe
# Nicky Romero
# Sticky Fingers
# Dimitri Vegas & Like Mike
# Norman Greenbaum
# Phantoms
# Orgânico
# Younger Brother
# Divinyls
# Mothers
# Reignwolf
# Suff Daddy
# I Like Fire
# James Brown & The Famous Flames
# Dope Lemon
# Darlingside
# Mansionair
# Nude Candy
# Teca Rosa
# Dierks Bentley
# Bautista
# Suff Problems
# Tedeschi Trucks Band
# October Rain
# Tev
# Edwin McCain
# Suff Daddy
# Alkaline Trio
# Beast
# Riff Raff
# Banda do Ballet
# Tevy Ray Vaughan
# Link Wray
# Odezenne
# Suzanne Vega
# betel.
# Bad Books
# Reik
# Elder Island
# The Smith Street Band
# Suff Daddy
# Screaming Trees
# M83
# Thom Yorke
# groove iris
# Lagum
# Alkaline Trio
# Sigma
# groove iris
# Motsu
# Rannar Sillard
# Racoon
# Olivia Newton-John
# Busted
# Shout Out Louds
# Mad Caddies
# Aqualung
# Son Purrp
# Burgundy Skies
# Tevola
# The Rascals
# Red Snapper
# D84
# M83
# Candlebox
# Alex Cameron
# Tequila Leaf
# Tequila River
# Tiana Major9
# Rosie Carney
# Busted
# Shame
# Pinegrove
# Alan Menken
# Elderbrook
# Busted
# Anita Baker
# Sun Ra
# Mxy's
# Chris Young
# Burna Boy
# Tequila Leaf
# Ethereal
# Jay-Jay Johanson
# Burna Boy
# Tequila
# Ethereal
# Ethereal
# Ethereal
# Ethereal
# Ethereal
# D92
# Davis
# Bryce Vine
# Ethereal
# Epik High
# Madeon
# Rick Nielsen
# Blr
# Michael Giacher
# BASSNECTAR
# Jamie Cullum
# Ethereal
# Rauw Alejandro
# Zebrahead
# Federico Montoya
# Dj Gabriel do Borel
# Ethereal
# Isaac Hayes
# Heilung
# Tev -
# Tevy James
# I Dreamed We Could Play Guitar
# PETA
# Sandro Cavazza
# Eucalyptic
# DJ Rashad
# POMME
# Rando Banton
# Ethereal
# Il Sognatore
# Sessy
# Cafe Au Lait
# Freddie Gibbs
# Tevr Simon
# Isaac Smith
# I Dream About You
# Aja
# Tevy Smith
# I See Stars
# Tevb3rb
# I Dreamin' You Dead
# Travis Barker
# I Dream Of Stars
# pyhlen
# I See Stars
# difesa
# L69
# Declan Mckenna
# Bikini Kill
# Möwe
# Declan J Donovan
# Sigríður
# Tomaso Giovanni Albinoni
# Vitaa
# Heart Attack Man
# Andrew Applepie
# August Alsina
# Møme
# Alexander Wolf
# I Dream Of Fighting
# Taylor Swift
# Red
# James Holden
# Hiroyuki Sawano
# DREAM DAILY
# Tevo
# Erik Satie
# Dimmu Borgir
# Cat Stevens
# Mino
# Tyler Ward
# Rollo
# Wando Warg
# Eros Ramazzotti
# Borgore
# Satori
# Inu X Boku
# Black Label Society
# Mon Laferte
# The Dear Hunter
# Kenny Loggins
# Them
# Jónsi
# Biffy Clyro
# The Real Mike McCready
# Stacey Kent
# Róné Lamborghini
# Ignacio Mendes
# Dave Brubeck
# SKYPE
# Orchestra Baobab
# Imagination
# Dennis Brown
# Eros Ramazzotti
# Bink
# Mike Williams
# Love
# Tom Morello
# Erasmo Carlos
# The Bird and the Bee
# Король и Шут
# The Oh Hellos
# Jónsi
# Jhay Cortez
# Panda Bear
# Kenny Rogers
# Fink
# Mohombi
# Calibre
# Algiers
# George Michael
# Chayanne
# The Oh Hellos
# Ryan Lizza
# Guo Pring
# The Good, the Bad & the Queen
# Puma Blue
# Fisk
# NCT 127
# Bicep
# Traffic
# Portico Quartet
# Shabazz Palaces
# Malibu Ken
# Avshalom
# Summer Citrus
# NCT 127
# Dre'es
# NCT 127
# Randy Crawford
# Vanessa Paradis
# Matt Cameron
# Prospector
# Donga
# Aventura
# Anita Baker
#
#
# [810 | 1932.99] loss=0.06 avg=0.91
# [820 | 1955.28] loss=0.03 avg=0.89
# [830 | 1977.51] loss=0.06 avg=0.88
# [840 | 1999.79] loss=0.10 avg=0.86
# [850 | 2022.04] loss=0.03 avg=0.85
# [860 | 2044.32] loss=0.07 avg=0.84
# [870 | 2066.56] loss=0.11 avg=0.82
# [880 | 2088.77] loss=0.07 avg=0.81
# [890 | 2110.94] loss=0.06 avg=0.80
# [900 | 2133.14] loss=0.07 avg=0.79
# [910 | 2155.37] loss=0.03 avg=0.77
# [920 | 2177.57] loss=0.03 avg=0.76
# [930 | 2199.79] loss=0.15 avg=0.75
# [940 | 2222.04] loss=0.04 avg=0.74
# [950 | 2244.27] loss=0.07 avg=0.73
# [960 | 2266.48] loss=0.06 avg=0.72
# [970 | 2288.73] loss=0.10 avg=0.71
# [980 | 2310.96] loss=0.05 avg=0.70
# [990 | 2333.22] loss=0.03 avg=0.69
# [1000 | 2355.49] loss=0.06 avg=0.68
# Saving checkpoint/run3/model-1000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.

# %% [markdown]
# ## Model Checkpoints
#
# Once the above finetuning is done, you'll find a `.rar` checkpoint of it in the file navigator to the left in `Files/models/355M`. Since this is just a demonstration of creating the model for `new_ai_rtists`, we'll skip the steps on saving and loading checkpoints to Drive. As always, see the original Colab for more info.

# %% [markdown]
# ## Generate Text From The Trained Model
#
# After you've trained the model, you can now generate text. `generate` generates a single text from the loaded model.

# %%
gpt2.generate(sess, run_name='run3')
# Out:
# Scott Lambert
# Blues Traveler
# James Brown
# Jony
# Groove Armada
# Static & Rock
# Nio Garcia
# Dayseeker
# James Brown
# BD
# Ylvis
# Tim Buckley
# Belly
# Kenny G
# Cigarettes After Sex
# La Femme
# Thekla
# Jaden
# Bakermat
# The Victor
# The Secret Sisters
# AXA
# Martha Reeves & The Vandellas
# BB King
# Marcus King
# George Ezra
# Dwayne Johnson
# BTS
# Weezer
# Young Thug
# LIL UZI VERT
# Arcade Fire
# Ellie Goulding
# Black Eyed Peas
# Lewis Capaldi
# Niara
# Dance Gavin Dance
# Nick Cave
# Wings
# Formosa
# Oliver Évilo
# S3RL
# The Ink Spots
# S3R3
# Slade
# Curbi
# Måns Zelmerlöw
# Night Moves
# Flobots
# Arctic Monkeys
# Hayley Williams
# Death in June
# Wintergatan
# Édith Piaf
# Tep No
# Jonny Greenwood
# Beach Goons
# Chloe x Halle
# Tegan and Sara
# Zero 7
# BLACK MIDI
# Tomaso Giovanni Cesari
# Easy Life
# Juice Newton
# Pusha T
# A$AP Twelvyy
# Glass Candy
# Blanck Mass
# Tejal Yann
# Eli.
# Mike Williams
# Ed Sheeran
# Blanck Mass
# The Lumineers
# Johann Sebastian Bach
# Lou Reed
# Blues Saraceno
# My Morning Jacket
# Sugabababababababababababababaco
# Monolord
# Yello
# Paul Weller
# Conor Oberst
# Weller
# Johann Sebastian Bach
# Lou Reed
# Johann Sebastian Bach
# George Gershwin
# Tim Buckley
# Blues Saraceno
# Sam Hunt
# Chimaira
# Van Halen
# Weezer
# Lil Durk
# Yaeji
# Dilja
# Martin Jensen
# S3RL
# Dreamer Boy
# A$AP Twelvyy
# Gus Dapperton
# Andra Day
# Victorious Cast
# Casey Veggies
# Zé Ramalho
# Blues Saraceno
# Mr. Bungle
# Eric Bellinger
# S3RL
# Faber
# Brytiago
# Antimatter
# White Denim
# Dorothy
# Nathaniel Rateliff & the Night Sweats
# Insomnium
# Nazareth
# Mike Williams
# Wilkinson
# Synkro
# JHNXT
# Böker
# Mike Williams
# Bluedoom
# Arnaldo Fernández
# Bad Company
# Duffy
# S3RL
# Gedz
# Oliver Évilo
# Sugabababababababababababababaco
# Monolord
# Yaeji
# Eluvium
# The Creed
# S3RLD
# Black Veil Brides
# Хаски танк (смысловые галлюцина)
# Trevor Something
# Летор Снайперы
# Acda en de Munnik
# Barker
# The Ataris
# Arvo Pärt
# Claudia Leitte
# Greta Van Fleet
# Chloe xoxo
# The Joy Formidable
# Aya Nakamura
# BlocBoy JB
# The Notwist
# Faber
# GOT7
# Michael Seyer
# The Following
# SF9
# Michael Seyer
# The Muzak Kids
# SF9
# Basshunter
# SFX
# Crim3s
# Clarence Carter
# YBN Nahmir
# The Wow
# Afshinwire
# Mohombi
# San Holo
# Böker
# Eluvium
# Delacruz
# X1
# The Funky DL
# Gorgon City
# Dalex
# Kojak
# Yello
# Peter Goldmark
# S3RL
# Miranda Cosgrove
# King Kong
# Freddie Gibbs & Madlib
# San Fermin
# Fuego
# DJ Osuna
# Retrovision
# Gavin Luke
# The Oh Hellos
# Fontella Amarone
# Vancouver Sleep Clinic
# Paul Revere & The Raiders
# Boulevard
# The Griswolds
# The Oh Hellos
# Foot Patrol
# River Hill
# Rosie Carney
# Little Mix
# Dj Esco
# Little Jesus
# Juvenile
# Maka.amaa
# TPWR
# Gavin Jennings
# Little Mix
# Dj Esco
# Dj Esco
# Dj Esco
# Dj Esco
# Dj Esco
# Dj Esco
# Dj Esco
# Dj Osuna
# Tejalessandro
# N

# %% [markdown]
# You can pass in a `prefix` to the generate function to force the text to start with a given character sequence and generate text from there (good if you add an indicator when the text starts).
#
# You can also generate multiple texts at a time by specifing `nsamples`. Unique to GPT-2, you can pass a `batch_size` to generate multiple samples in parallel, giving a massive speedup (in Colaboratory, set a maximum of 20 for `batch_size`).
#
# Other optional-but-helpful parameters for `gpt2.generate` and friends:
#
# *  **`length`**: Number of tokens to generate (default 1023, the maximum)
# * **`temperature`**: The higher the temperature, the crazier the text (default 0.7, recommended to keep between 0.7 and 1.0)
# * **`top_k`**: Limits the generated guesses to the top *k* guesses (default 0 which disables the behavior; if the generated output is super crazy, you may want to set `top_k=40`)
# * **`top_p`**: Nucleus sampling: limits the generated guesses to a cumulative probability. (gets good results on a dataset with `top_p=0.9`)
# * **`truncate`**: Truncates the input text until a given sequence, excluding that sequence (e.g. if `truncate='<|endoftext|>'`, the returned text will include everything before the first `<|endoftext|>`). It may be useful to combine this with a smaller `length` if the input texts are short.
# *  **`include_prefix`**: If using `truncate` and `include_prefix=False`, the specified `prefix` will not be included in the returned text.
#
#
# For bulk generation, you can generate a large amount of text to a file and sort out the samples locally on your computer. The next cell will generate a generated text file with a unique timestamp.
#
# You can rerun the cells as many times as you want for even more generated texts!

# %%
gen_file = 'gpt2_gentext_{:%Y%m%d_%H%M%S}.txt'.format(datetime.utcnow())

gpt2.generate_to_file(sess,
                      destination_path=gen_file,
                      length=1023,
                      temperature=0.7,
                      nsamples=100,
                      batch_size=20,
                      run_name='run3'
                      )

# %%
# may have to run twice to get file to download
files.download(gen_file)

# %% [markdown]
# ## Conclusion
#
# Just following along and running the cells in this Colab, you'll produce a GPT-2 model, checkpoint, AND generated text(s) using the exact methodology I did to create `new_ai_rtists`. Of course, it should be pretty easy to adapt all of this to whatever text-based project you want, so **GO NUTS!**

# %% [markdown]
# ##NOTE:
# You could make a pretty good argument that, since GPT-2 was trained on internet data, it's more likely to spit out artist names that already belong to real artists, whether or not they're in our initial dataset. It's my intention to replicate this whole process using a 'fresh' text-generation RNN and see how the results compare.
#
# So, be on the lookout for updated documentation!
